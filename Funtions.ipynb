# %% [markdown]
# <a href="https://colab.research.google.com/github/kandiwapa/Functions-from-zero/blob/main/Funtions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Styles of Functions

# %%
def simple():pass

# %%
def simple2():
  print(simple2)

# %% [markdown]
# ### Most useful

# %%
def my_worker(fruit):
  statement = f"My Favourite meal is chicken and {fruit}"
  meals = {"dinner": statement}
  return meals

# %%
meals = my_worker("apple")

# %%
meals
# Out:
# {'dinner': 'My Favourite meal is chicken and apple'}

# %%
meals.keys()
# Out:
# dict_keys(['dinner'])

# %%
def humans(food):
  consume = food["dinner"]
  return consume

# %%
my_meal = humans(meals)
print(f"I want my meal. It will be: ")
# Out:
# I want my meal. It will be:
