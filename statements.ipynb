# %% [markdown]
# <a href="https://colab.research.google.com/github/kandiwapa/Functions-from-zero/blob/main/statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Learning Statments

# %%
print("hello World")
# Out:
# hello World

# %% [markdown]
# ##Variables

# %%
variable = 1
